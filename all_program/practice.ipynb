# %%
list1=['apple','banana','kiwi','orange']
newlist= []
for x in list1:
    if "a" in x:
        newlist.append(x)
print(newlist)
# Out:
# ['apple', 'banana', 'orange']

# %%
list1=['apple','banana','kiwi','orange']
newlist = [x for x in list1 if "a" in x]
print(newlist)
# Out:
# ['apple', 'banana', 'orange']

# %%
list1=['apple','banana','kiwi','orange']
newlist = [x for x in list1 if "a" not in x]
print(newlist)
# Out:
# ['kiwi']

# %%
day= 4
match day:
  case 1|2|3|4|5: print("Today is a weekday")
  case 6|7: print("I love weekends!")
# Out:
# Today is a weekday

# %%
def myfun(n):
    if n>1:
        for i in range(2,n):
            if n%i==0:
                print("not prime")
                break
            else:
                print("prime")
                break
    else:
        print("not prime")
myfun(11)
# Out:
# prime

# %%
def myfun(row):
    for i in range(row):
        for j in range(row-i):
            print(" ",end="")
        for k in range(2*i+1):
            print("*",end="")
        print()
myfun(5)
# Out:
#      *
#     ***
#    *****
#   *******
#  *********

# %%
def myfun(row):
    for i in range(row):
        for j in range(row):
            print("*",end=" ")
        print()
myfun(7)
# Out:
# * * * * * * *
# * * * * * * *
# * * * * * * *
# * * * * * * *
# * * * * * * *
# * * * * * * *
# * * * * * * *

# %%
def myfun(row,col):
    for i in range(row):
        for j in range(col):
            if i==0 or i==row-1 or j==0 or j==col-1:
                print("*", end=" ")
            else:
                print(" ",end=" ")
        print()
myfun(5,5)
# Out:
# * * * * *
# *       *
# *       *
# *       *
# * * * * *

# %%
def myfun(person):
    print("name:",person['name'])
    print("age:",person['age'])
one={"name":"jaydip","age":20,"city":"surat"}
myfun(one)
# Out:
# name: jaydip
# age: 20

# %%
def myfun(*number):
    total=0
    for i in number:
        total+=i
    print(total)
myfun(10,20,30,40,50)
# Out:
# 150

# %%
def myfun(*numbers):
    if numbers == 0:
        return None
    max_no = numbers[0]
    for num in numbers:
        if num > max_no:
            max_no = num
    return max_no
print(myfun(10,20,30,40))
# Out:
# 40

# %%
def count_no(n):
    if n <= 0:
        return 0
    else:
        print(n)
        count_no(n-1)
count_no(7)
# Out:
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
def fact(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n*fact(n-1)
print(fact(5))
# Out:
# 120

# %%
def fibonacii(n):
    if n <= 1:
        return n
    else:
        return fibonacii(n-1) + fibonacii(n-2)
print(fibonacii(7))
# Out:
# 13

# %%
def sum_list(number):
    if len(number) == 0:
        return 0
    else:
        return number[0] + sum_list(number[1:])
num = [10,20,30]
print(sum_list(num))
# Out:
# 60

# %%
def find_max(number):
    if len(number) == 1:
        return number[0]
    else:
        max_no = find_max(number[1:])
        return number[0] if number[0] > max_no else max_no
num= [10,5,65,34,2,87,8,6,34]
print(find_max(num))
# Out:
# 87

# %%
import datetime
x= datetime.datetime.now()
print(x)
# Out:
# 2026-04-24 15:56:58.345101

# %%
import datetime
x= datetime.datetime.now()
print(x.strftime("%a")) # day name sort
print(x.strftime("%a")) # day name long
print(x.strftime("%b")) # month name sort
print(x.strftime("%a")) # month name long
print(x.strftime("%d")) # day in month
print(x.strftime("%m")) # month in year
print(x.strftime("%y")) # number of year sort
print(x.strftime("%Y")) # number of year long
print(x.strftime("%H")) # hour in 1-24
print(x.strftime("%I")) # hour in 1-12
print(x.strftime("%M")) # minute of hour
print(x.strftime("%S")) # second for minute
print(x.strftime("%w")) # number of day for week
print(x.strftime("%u")) # number of day for week
print(x.strftime("%x")) # show date
print(x.strftime("%X")) # show time
print(x.strftime("%c")) # local time and date
# Out:
# Fri
# Fri
# Apr
# Fri
# 24
# 04
# 26
# 2026
# 15
# 03
# 56
# 58
# 5
# 5
# 04/24/26
# 15:56:58
# Fri Apr 24 15:56:58 2026

# %%
import math
x1=max(12,56,34,89,23)
print("max(12,56,34,89,23):",x1)
x2=min(12,56,34,89,23)
print("min(12,56,34,89,23):",x2)

#absolute and power
x3=abs(-45)
print("abs(-45):",x3)
x4=pow(2,3)
print("pow(2,3):",x4)

#square root, ceil, floor, pi
x5=math.sqrt(64)
print("sqrt(64):",x5)
x6=math.ceil(6.5)
print("ceil(6.5):",x6)
x7=math.floor(6.5)
print("floor(6.5):",x7)
x8=math.pi
print("pi:",x8)
# Out:
# max(12,56,34,89,23): 89
# min(12,56,34,89,23): 12
# abs(-45): 45
# pow(2,3): 8
# sqrt(64): 8.0
# ceil(6.5): 7
# floor(6.5): 6
# pi: 3.141592653589793

# %%
def divide(a,b):
    try:
        a=int(a)
        b=int(b)
        return a/b
    except ZeroDivisionError:
        return "zero division are not possible"
    except:
        return "enter interger no"
x=input("enter first value")
y=input("enter second value")
print(divide(x,y))
# Out:
# enter interger no

# %%
def myfun(row):
    try:
        row=int(row)
        for i in range(1,row+1):
            for j in range(row-i):
                print(" ",end=" ")
            for k in range(2*i-1):
                print("*",end=" ")
            print()
    except ValueError:
        print("Value Error Generated")
    except:
        print("Error Generated")
x=input("enter any no")
myfun(x)
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
row=5
for i in range(row,0,-1):
    for j in range(row-i):
        print(" ",end=" ")
    for k in range(2*i-1):
        print("*",end=" ")
    print()
# Out:
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *

# %%
def changecase(n):
    try:
        row=int(n)
        def changecase(fun):
            def inner():
                if row>=1:
                    for i in range(row,0,-1):
                        for j in range(row-i):
                            print(" ",end=" ")
                        for k in range(2*i-1):
                            print("*",end=" ")
                        print()
                    fun()
                else:
                    print("enter positive no(1,2,3...,n)")
            return inner
        return changecase
    except ValueError:
        print("value error generated")
    except:
        print("error generated")
x=input("enter int no")
@changecase(x)
def myfun():
    print( "_._piramid printed_._")
myfun()
# Out:
# * * * * * * * * * * *
#   * * * * * * * * *
#     * * * * * * *
#       * * * * *
#         * * *
#           *
# _._piramid printed_._

# %%
def myfun(a):
    try:
        a=int(a)
    except ValueError:
        print("value error generated")
    except:
        print("error generated")
    else:
        if a%4==0:
            leap= list(filter(lambda a:a%4==0, [a]))
            print("leap year",leap)
        else:
            not_leap= list(filter(lambda a:a%4!=0, [a]))
            print("not leap",not_leap)
    finally:
        print("leap year program")
x= input("enter year to check leap year or not:")
myfun(x)
# Out:
# leap year [2000]
# leap year program

# %%
def myfun(n):
    try:
        n=int(n)
        list_name= []
        for i in range(n):
            val = input("enter any value:")
            list_name.append(val)
        print("user entered value:",list_name)
        sorted_list= sorted(list_name, key=lambda  x:x)
        print("sorted value:",sorted_list)
    except ValueError:
        print("value error genrated please enter int no")
    except:
        print("exception generated")
a=input("enter number:")
myfun(a)
# Out:
# user entered value: ['3', '2', '6', '2', '3']
# sorted value: ['2', '2', '3', '3', '6']

# %%
def sum_number(number):
    if len(number) == 0:
        return 0
    else:
        return number[0] + sum_number(number[1:])
list_num=[]
for i in range(5):
    no= input("enter five time number:")
    try:
        no=int(no)
        list_num.append(no)
    except:
        print("enter integer no")
        break
list1=list_num
print("entered no:",list1)
num = [int(x) for x in list1]
print("total for enter no:",sum_number(num))
# Out:
# entered no: [32, 32, 21, 32, 21]
# total for enter no: 138

# %%
class One:
    def myfun(self, n):
        self.a = n
        for i in range(self.a + 1):
            for j in range(self.a - i):
                print(" ", end="")
            for k in range(2 * i - 1):
                print("*", end="")
            print()

a = One()
a.myfun(5)
# Out:
#
#     *
#    ***
#   *****
#  *******
# *********

# %%
class One:
    def myfun(self,n,compare):
        self.compare =compare
        self.num = n
        if self.compare=="up":
            for i in range(self.num+1):
                for j in range(self.num - i):
                    print(" ",end=" ")
                for k in range(2*i-1):
                    print("*",end=" ")
                print()
        elif self.compare=="down":
            for i in range(self.num,0,-1):
                for j in range(self.num - i):
                    print(" ",end=" ")
                for k in range(2*i-1):
                    print("*",end=" ")
                print()
        else:
            print("please enter up or down keyword")
obj = One()
try:
    a = int(input("enter number of row(1<=2,3...,n)"))
    b = input("enter up or down keyword")
    print("your entered number of row is:",a)
    print("your entered string is:",b)
except:
    print("generate error")
    a = None
else:
    obj.myfun(a,b)
finally:
    if a is not None:
        if b == "up" or b == "down":
            print("program execute")
        else:
            print("enter string error")
    else:
        print("integer error generated")
# Out:
# your entered number of row is: 5
# your entered string is: up
#
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *
# program execute

# %%
import datetime
from pytz import timezone
utc = datetime.datetime.now(datetime.timezone.utc)
ind = utc.astimezone(timezone("Asia/Kolkata"))
print("utc:", utc,"  ", "ind:", ind)
# Out:
# utc: 2026-05-01 05:23:04.654417+00:00    ind: 2026-05-01 10:53:04.654417+05:30

# %%
import datetime

today= datetime.datetime.now()

add_day = today + datetime.timedelta(days=2)

month=today.month + 1
year= today.year
if month>12:
    month =1
    year +=1
add_month= today.replace(month=month , year=year)

add_year = today.replace(year=today.year+1)

add_hour = today + datetime.timedelta(hours=1)
add_minute = today + datetime.timedelta(minutes=1)
add_second = today + datetime.timedelta(seconds=1)

print(today)
print("day + 1:",add_day)
print("month +1:",add_month)
print("year + 1:",add_year)
print("hour + 1:",add_hour)
print("minute + 1:",add_minute)
print("second + 1:",add_second)
# Out:
# 2026-05-01 11:21:28.869952
# day + 1: 2026-04-29 11:21:28.869952
# month +1: 2026-06-01 11:21:28.869952
# year + 1: 2027-05-01 11:21:28.869952
# hour + 1: 2026-05-01 12:21:28.869952
# minute + 1: 2026-05-01 11:22:28.869952
# second + 1: 2026-05-01 11:21:29.869952

# %%
import datetime
from pytz import timezone

utc_time = datetime.datetime.now(datetime.timezone.utc)
india_time = utc_time.astimezone(timezone("Asia/Kolkata"))

add_day = india_time + datetime.timedelta(days=2)

month = india_time.month + 2
year = india_time.year
if month > 12:
    month = 1
    year += 1
add_month = india_time.replace(month=month, year=year)

add_year = india_time.replace(year=india_time.year+2)

dt= datetime.datetime.combine(datetime.date.today(), india_time.time())
add_hour = dt + datetime.timedelta(hours=2)

add_minute = dt + datetime.timedelta(minutes=20)

add_second = dt +  datetime.timedelta(seconds=20)
# add_hour = india_time + datetime.timedelta(hours=2)

print("UTC Time:",utc_time)
print("INDIA Time:",india_time)
print("Added 2 Day",add_day)
print("Addde 2 Month:",add_month)
print("Added 2 Year",add_year)
print("Added 2 Hour",add_hour)
print("Added 20 Minute",add_minute)
print("Added 20 Second",add_second)
# Out:
# UTC Time: 2026-05-01 05:41:34.550759+00:00
# INDIA Time: 2026-05-01 11:11:34.550759+05:30
# Added 2 Day 2026-05-03 11:11:34.550759+05:30
# Addde 2 Month: 2026-07-01 11:11:34.550759+05:30
# Added 2 Year 2028-05-01 11:11:34.550759+05:30
# Added 2 Hour 2026-05-01 13:11:34.550759
# Added 20 Minute 2026-05-01 11:31:34.550759
# Added 20 Second 2026-05-01 11:11:54.550759
