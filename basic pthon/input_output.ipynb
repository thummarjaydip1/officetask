# %% [markdown]
# ## Input and Output

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("Hello world")
print("i am learning python")
print("it is awsome")
# Out:
# Hello world
# i am learning python
# it is awsome

# %%
print("Hello world", end="")
print("i am learning python")
# Out:
# Hello worldi am learning python

# %%
print(234325)
print("Hello", 23, "world")
# Out:
# 234325
# Hello 23 world

# %%
s = "barad"
print(s)
# Out:
# barad

# %%
s = "naman"
age = 21
city = "surat"
print(s, age, city)
# Out:
# naman 21 surat

# %%
print("Hello");
# Out:
# Hello

# %%
name1 = "jay"
name2 = "dip"
name3 = "raj"
name4 = "ram"
print(name1,name2,name3,name4,sep=", ")
# Out:
# jay, dip, raj, ram

# %%
paragraph = """
    This is animal,
    This is Dog,
    This is Cat,
    This is Monkey
"""
print(paragraph)
# Out:
#     This is animal,
#     This is Dog,
#     This is Cat,
#     This is Monkey

# %%
print("enter your name")
name = input()
print(name)
# Out:
# enter your name
# manan

# %%
name = input("enter name")
print(name)
# Out:
# jay

# %%
name = input("enter name")
print(name)
animal = input("enter animal name")
fruit = input("enter fruits name")
print(animal, fruit)
# Out:
# jay
# dog apple

# %%
num1 = input("enter first naumber")
num2 = input("enter second naumber")
print(num1)
print(num2)
print(num1 + num2)
# Out:
# 11
# 12
# 1112

# %%
num1 = int(input("enter first naumber"))
num2 = int(input("enter second naumber"))
print(num1)
print(num2)
print(num1 + num2)
# Out:
# 11
# 12
# 23

# %%
name = input("enter any name")
print("Hello", name, "welcome")
# Out:
# Hello jay welcome

# %%
x, y = input("enter two number").split()
print(x, y)
# Out:
# 11 12

# %%
a = int(input("How are you old:"))
b = float(input("Evalute 7/2:"))
print(a, b)
# Out:
# 11 11.0

# %%
name = input()
city = input()
print("enter name:", name)
print("enter city:", city)
# Out:
# enter name: jay
# enter city:  surat

# %%
width = int(input("enter width"))
height = int(input("enter height"))

print("Width is:",width)
print("Height is:",height)

area = width * height
print("Area is",area)
# Out:
# Width is: 11.0
# Height is: 12.0
# Area is 132.0

# %%
amount = float(input("Enter amount:"))
rate = float(input("Enter rate of interest:"))

interest = amount*rate/100
print("Amount:", amount, "Rate:", rate, "Interest:", interest)
# Out:
# Amount: 1000.0 Rate: 5.5 Interest: 55.0
