# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
print(a)
print(type(a))
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange']
# <class 'list'>

# %%
a = [12,"hello",23.43,2+3j,True]
print(a)
# Out:
# [12, 'hello', 23.43, (2+3j), True]

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
print(a[1])
# Out:
# banana

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
print(a[2:])
# Out:
# ['mango', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
print(a[1:3])
# Out:
# ['banana', 'mango']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
print(a[-1])
# Out:
# orange

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
print(a[-4:-1])
# Out:
# ['banana', 'mango', 'kiwi']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
print(a[::-1])
# Out:
# ['orange', 'kiwi', 'mango', 'banana', 'apple']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
if "mango" in a:
    print("yes")
# Out:
# yes

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a[2] = "pineapple"
print(a)
# Out:
# ['apple', 'banana', 'pineapple', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a[1:3] = ["pineapple","chickoo"]
print(a)
# Out:
# ['apple', 'pineapple', 'chickoo', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a.insert(2,"chickoo")
print(a)
# Out:
# ['apple', 'banana', 'chickoo', 'mango', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a.append("chickoo")
print(a)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange', 'chickoo']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
b = ("chickoo", "pineapple")
a.extend(b)
print(a)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange', 'chickoo', 'pineapple']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a.remove("banana")
print(a)
# Out:
# ['apple', 'mango', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a.pop()
print(a)
# Out:
# ['apple', 'banana', 'mango', 'kiwi']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a.pop(2)   # 2 index item remove
print(a)
# Out:
# ['apple', 'banana', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
del a[2]
print(a)
# Out:
# ['apple', 'banana', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 3
#       1 a = ["apple", "banana", "mango", "kiwi", "orange"]
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
for i in a:
    print(i)
# Out:
# apple
# banana
# mango
# kiwi
# orange

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
for i in range(len(a)):
    print(a[i])
# Out:
# apple
# banana
# mango
# kiwi
# orange

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
i = 0
while i < len(a):
    print(a[i])
    i = i + 1
# Out:
# apple
# banana
# mango
# kiwi
# orange

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
new = []

for i in a:
    if "n" in i:
        new.append(i)

print(a)
print(new)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange']
# ['banana', 'mango', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
new = [i for i in a if "a" in i]
print(a)
print(new)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange']
# ['apple', 'banana', 'mango', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
new = [i for i in a if "apple" != i]
print(a)
print(new)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange']
# ['banana', 'mango', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
new = [i.upper() for i in a]
print(a)
print(new)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange']
# ['APPLE', 'BANANA', 'MANGO', 'KIWI', 'ORANGE']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a.sort()
print(a)
# Out:
# ['apple', 'banana', 'kiwi', 'mango', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a.sort(reverse=True)
print(a)
# Out:
# ['orange', 'mango', 'kiwi', 'banana', 'apple']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a.reverse()
print(a)
# Out:
# ['orange', 'kiwi', 'mango', 'banana', 'apple']

# %%
a = [75,12,87,90,25,32,87,15]
a.sort()
print(a)
# Out:
# [12, 15, 25, 32, 75, 87, 87, 90]

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
b = a.copy()
print(b)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
b = list(a)
print(b)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
b = ["chickoo", "pineapple"]
c = a+b
print(c)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'orange', 'chickoo', 'pineapple']

# %%
a = ["apple", "banana", "mango", "kiwi", "orange", "kiwi"]
print(a.count("kiwi"))
# Out:
# 2

# %%
a = ["apple", "banana", "mango", "kiwi", "orange"]
a.clear()
print(a)
# Out:
# []
