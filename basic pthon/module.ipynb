# %% [markdown]
# ## Python Module

# %% [markdown]
# ##### user define module

# %%
from python_module import nornal_fun as nm
from python_module import nornal_fun
import python_module

nornal_fun()
nm()
python_module.nornal_fun()
# Out:
# Hello User
# Hello User
# Hello User

# %%
from python_module import Calculator

# import importlib
# importlib.reload(python_module)

add = Calculator.addtion(112, 434)
print("addition:", add)

sub = Calculator.substraction(242, 121)
print("substraction:", sub)

mul = Calculator.multiplication(12,10)
print("multiplication:", mul)

div = Calculator.division(1255,100)
print("division:", div)
# Out:
# addition: 546
# substraction: 121
# multiplication: 120
# division: 12.55

# %%
from python_module import mydict

print(mydict)
print()

print("access name:", mydict["name"])
print()

print("key  :  value")
for key,value in mydict.items():
    print(key, ":", value)
# Out:
# {'name': 'jaydip', 'age': 21, 'city': 'bagasara', 'email': 'jaydip@gmail.com'}
#
# access name: jaydip
#
# key  :  value
# name : jaydip
# age : 21
# city : bagasara
# email : jaydip@gmail.com

# %% [markdown]
# ##### built-in module

# %%
import random 

print(random.randint(1,5))
# Out:
# 1

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ##### External (third party) module

# %%
import requests

r = requests.get("htts://example.com")
print(r.status_code)

# %% [markdown]
# ##### Package module

# %%
# from mypackage import utils
# print(utils.some_func())
