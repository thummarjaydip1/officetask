# %% [markdown]
# ## Operator

# %% [markdown]
# ### Arithmetic Operator

# %%
a = 10
b = 5
print("a:", a)
print("b:", b)

res = a + b
print("addition:", res)

res = a - b
print("substraction:", res)

res = a * b
print("multiplication:", res)

res = a / b
print("division:", res)

res = a % b
print("modular:", res)

res = a ** b
print("exponentiation:", res)  # 10*10*10*10*10

b = 3
res = a // b
print("floor division:", res)  # roud result 3.333 ans convert to 3
# Out:
# a: 10
# b: 5
# addition: 15
# substraction: 5
# multiplication: 50
# division: 2.0
# modular: 0
# exponentiation: 100000
# floor division: 3

# %% [markdown]
# ### Assignment Operator

# %%
a = 5
print("a:", a)
# Out:
# a: 5

# %%
a += 3
print("a:", a)
# Out:
# a: 8

# %%
a = 5
a -= 3
print("a:", a)
# Out:
# a: 2

# %%
a = 5
a *= 3
print("a:", a)
# Out:
# a: 15

# %%
a = 5
a /= 2
print("a:", a)
# Out:
# a: 2.5

# %%
a = 5
a %= 3
print("a:", a)
# Out:
# a: 2

# %%
a = 5
a //= 3
print("a:", a) # 1.666 convert 1
# Out:
# a: 1

# %%
a = 5
a **= 3
print("a:", a) # 5*5*5=125
# Out:
# a: 125

# %% [markdown]
# ### Ternary Operator

# %%
num = 6

x = "week end" if num > 5 else "week day"
print(x)
# Out:
# week end

# %%
num = 3
x = "fri" if num==5 else "sat" if num==6 else "sun" if num==7 else "weekday"
print(x)
# Out:
# weekday

# %%
num = 456
x = "even number" if num%2==0 else "odd number"
print(num,"is",x)
# Out:
# 456 is even number

# %%
num = -543
x = "positive number" if num > 0 else "nagative number" if num < 0 else "Zero"
print(x)
# Out:
# nagative number

# %%
num = 7
x = ("odd", "even")[num%2==0]
print(x)
# Out:
# odd

# %%
a = 20
b = 30
x = "a is big number" if a > b else "b is big number" if b > a else "equal number"
print(x)
# Out:
# b is big number

# %% [markdown]
# ### Comparision Operator

# %%
a = 10
b = 10

print(a == b)
# Out:
# True

# %%
a = 10
b = 10
print(a != b)
# Out:
# False

# %%
a = 10
b = 20
print(a > b)
# Out:
# False

# %%
a = 10
b = 20
print(a < b)
# Out:
# True

# %%
a = 10
b = 10
print(a >= b)
# Out:
# True

# %%
a = 20
b = 10
print(a <= b)
# Out:
# False

# %% [markdown]
# ### Logical Operator

# %%
a = 5 
print(a > 3 and a < 10)
print(a > 3 and a > 10)
# Out:
# True
# False

# %%
a = 5 
print(a > 3 or a < 10)
print(a > 3 or a > 10)
# Out:
# True
# True

# %%
a = 5 
print(not(a > 3 and a < 10))

print(a is not 5)
# Out:
# False
# False
# <>:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\blackwolve\AppData\Local\Temp\ipykernel_13256\1277354841.py:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   print(a is not 5)

# %% [markdown]
# ### Indentity Operator

# %%
a = 10
b = 20 
c = a

print(a is b)   # is means ==   
print(a is c)
# Out:
# False
# True

# %%
a = 10
b = 20 
c = a

print(a is not b)   # is not means !=
print(a is not c)
# Out:
# True
# False

# %%
a = ["apple", "banana"]
b = ['apple', "mango"]

print(a is b)
print(a is not b)
# Out:
# False
# True

# %% [markdown]
# ### Membership Operator

# %%
a = "Hello world"
print("O" in a)
print("o" in a)
# Out:
# False
# True

# %%
a = "Hello world"
print("O" not in a)
print("o" not in a)
# Out:
# True
# False

# %%
a = [10,20,30,40,50]

print(20 in a)
print(20 not in a)
# Out:
# True
# False

# %%
a = ["apple","mango","banana","kiwi","pineapple"]

print("kiwi" in a)
print("kiwi" not in a)
# Out:
# True
# False

# %%
var = {(10,20),30,40}
a = 10
b = 20
print ((a,b) in var)
# Out:
# True

# %% [markdown]
# ### Bitwise Operator

# %%
a = 10
b = 4

print("a & b =", a & b)
# Out:
# a & b = 0

# %%
a = 10
b = 4

print("a | b =", a | b)
# Out:
# a | b = 14

# %%
a = 10
b = 4

print("a ^ b =", a ^ b)
# Out:
# a ^ b = 14

# %%
a = 10
b = 14

print("~a =", ~a)
print("~b =", ~b)
# Out:
# ~a = -11
# ~b = -15

# %%
a = 5
print ("a:",a, "a<<2:", a<<2)
# Out:
# a: 5 a<<2: 20

# %%
a = 5
print ("a:",a, "a<<2:", a>>2)
# Out:
# a: 5 a<<2: 1
