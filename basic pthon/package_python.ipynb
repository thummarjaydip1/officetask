# %% [markdown]
# ## Package in Python

# %%
from package import math_operation as mo

print(mo.add(11,22))
# Out:
# 33

# %%
from package import math_operation as mo

print(mo.mul(11,2,2,2))
# Out:
# 88

# %%
from package.string_operation import upper_case

print(upper_case("hello, Jaydip"))
# Out:
# HELLO, JAYDIP
