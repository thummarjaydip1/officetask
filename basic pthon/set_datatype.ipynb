# %% [markdown]
# ## Set datatype

# %%
a = {"apple", 23, 54.42, True, "mango", "chickoo"}
print(a)
print(len(a))
print(type(a))
# Out:
# {True, 54.42, 23, 'chickoo', 'mango', 'apple'}
# 6
# <class 'set'>

# %%
a = {"apple","banana","mango","kiwi"}
for i in a:
    print(i)
# Out:
# banana
# mango
# kiwi
# apple

# %%
a = {"apple","banana","mango","kiwi"}
print("apple" in a)
# Out:
# True

# %%
a = {"apple","banana","mango","kiwi"}
a.add("orange")
print(a)
# Out:
# {'kiwi', 'orange', 'mango', 'apple', 'banana'}

# %%
a = {"apple","banana","kiwi"}
b = {"orange","mango"}
a.update(b)
print(a)
# Out:
# {'kiwi', 'orange', 'banana', 'mango', 'apple'}

# %%
a = {"apple","banana","mango","kiwi"}
a.remove("mango")
print(a)
# Out:
# {'banana', 'kiwi', 'apple'}

# %%
a = {"apple","banana","mango","kiwi"}
a.discard("banana")
print(a)
# Out:
# {'mango', 'kiwi', 'apple'}

# %%
a = {"apple","banana","mango","kiwi"}
b= a.pop()
print(b)
print(a)
# Out:
# banana
# {'mango', 'kiwi', 'apple'}

# %%
a = {"apple","banana","mango","kiwi"}
a.clear()
print(a)
# Out:
# set()

# %%
a = {"apple","banana","mango","kiwi"}
b = {"apple","mango","orange","kiwi"}
c = a.union(b)
print(c)
# Out:
# {'kiwi', 'orange', 'mango', 'apple', 'banana'}

# %%
a = {"apple","banana","mango","kiwi"}
b = {"apple","mango","orange","kiwi"}
c = a | b
print(c)
# Out:
# {'kiwi', 'orange', 'mango', 'apple', 'banana'}

# %%
a = {"apple","banana","mango","lemon"}
b = {"apple","mango","orange","kiwi"}
c = a.intersection(b)
print(c)
# Out:
# {'mango', 'apple'}

# %%
a = {"apple","banana","mango","kiwi"}
b = {"apple","mango","orange","kiwi"}
c = a & b
print(c)
# Out:
# {'mango', 'kiwi', 'apple'}

# %%
a = {"apple","banana","mango","kiwi"}
b = {"apple","mango","orange","lemon"}
a.intersection_update(b)
print(a)
# Out:
# {'mango', 'apple'}

# %%
a = {"apple","banana","mango","kiwi"}
b = {"apple","mango","orange","lemon"}
c = a.difference(b)
print(c)
# Out:
# {'banana', 'kiwi'}

# %%
a = {"apple","banana","mango","kiwi"}
b = {"apple","mango","orange","lemon"}
c = a - b
print(c)
# Out:
# {'banana', 'kiwi'}

# %%
a = {"apple","banana","mango","kiwi"}
b = {"apple","mango","orange","lemon"}
c =a.symmetric_difference(b)
print(c)
# Out:
# {'kiwi', 'orange', 'lemon', 'banana'}

# %%
a = {"apple","banana","mango","kiwi"}
b = {"apple","mango","orange","lemon"}
c = a ^ b
print(c)
# Out:
# {'kiwi', 'orange', 'lemon', 'banana'}

# %%
a = ({"apple","banana","mango","kiwi"})
print(a)
print(len(a))
print(type(a))
# Out:
# {'banana', 'mango', 'kiwi', 'apple'}
# 4
# <class 'set'>

# %%
a = ({"apple","banana","mango","kiwi"})
b = a.copy()
print(b)
# Out:
# {'banana', 'mango', 'kiwi', 'apple'}

# %%
a = ({"apple","banana","mango","kiwi"})
b = ({"apple","lemon","orange","kiwi"})
c = a.difference(b)
print(c)
# Out:
# {'banana', 'mango'}

# %%
a = ({"apple","banana","mango","kiwi"})
b = ({"apple","lemon","orange","kiwi"})
c = a.intersection(b)
print(c)
# Out:
# {'kiwi', 'apple'}

# %%
a = ({"apple","banana","mango","kiwi"})
b = ({"apple","orange","lemon","kiwi"})
c = a.union(b)
print(c)
# Out:
# {'kiwi', 'orange', 'mango', 'apple', 'lemon', 'banana'}

# %%
a = frozenset({1, 2})
b = frozenset({3, 4})
c = frozenset({2, 3})
print(a.isdisjoint(b))
print(a.isdisjoint(c))
# Out:
# True
# False
