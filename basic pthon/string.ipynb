# %% [markdown]
# ## String

# %%
a = "hello wrold"
print(a)
# Out:
# hello wrold

# %%
# multi line string 
a = """
    hello
    world
    bye
"""
print(a)
# Out:
#     hello
#     world
#     bye

# %%
a = "hello world"
print(a[3])
# Out:
# l

# %%
a = "hello world"
print(a[-3])
# Out:
# r

# %%
a = "hello world"
for char in a:
    print(char)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
a = "hello world"
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 a = "hello world"
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
a = "hello world"
print(len(a))
# Out:
# 11

# %%
a = "Hello World"
print(a.upper())
print(a.lower())
# Out:
# HELLO WORLD
# hello world

# %%
a = "     Hello world     "
print(a.strip())

a = "Hello world"
print(a.replace("Hello", "Hey"))
# Out:
# Hello world
# Hey world

# %%
a = "hello " 
b = "world"
print(a + b)      # concted string

print(a * 3)      # repetation string
# Out:
# hello world
# hello hello hello

# %%
# formating string
name = "jaydip"
age = 21
print(f"name is: {name} and age is: {age}")
# Out:
# name is: jaydip and age is: 21

# %%
# formating string
name = "my name is {} i am {} year old".format("jay",21)
print(name)
# Out:
# my name is jay i am 21 year old

# %%
# string membership testing
a = "HelloWorld"
print("Hel" in a)
print("World" in a)
# Out:
# True
# True

# %%
name1 = "jay"
name2 = "jay"
print(name1 in name2)
# Out:
# True

# %%
a = "python is programing language"
b = a.split()
print(b)
# Out:
# ['python', 'is', 'programing', 'language']

# %%
a= "python"
b= list(a)
print(b)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']
