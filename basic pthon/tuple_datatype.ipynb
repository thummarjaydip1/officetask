# %% [markdown]
# ## Tuple datatype

# %%
a = ("apple","banana","mango")
print(a)
# Out:
# ('apple', 'banana', 'mango')

# %%
a = ("apple","banana","mango")
print(type(a))
print(len(a))
# Out:
# <class 'tuple'>
# 3

# %%
a = ("apple","banana","mango",12, 234.23,True)
print(a)
# Out:
# ('apple', 'banana', 'mango', 12, 234.23, True)

# %%
a= "Hello"
print(tuple(a))
# Out:
# ('H', 'e', 'l', 'l', 'o')

# %%
a = ("apple","banana","mango","kiwi","lemon")
print(a[2:])
# Out:
# ('mango', 'kiwi', 'lemon')

# %%
a = ("apple","banana","mango","kiwi","lemon")
print(a[-1])
# Out:
# lemon

# %%
a = ("apple","banana","mango","kiwi","lemon")
print(a[:-1])
# Out:
# ('apple', 'banana', 'mango', 'kiwi')

# %%
num = (10, 20, 30, 40, 50, 60)
res = num[::2]
print(res)
# Out:
# (10, 30, 50)

# %%
num = (10, 20, 30, 40, 50, 60)
res = num[::-1]
print(res)
# Out:
# (60, 50, 40, 30, 20, 10)

# %%
a = ("apple","banana","mango","kiwi","lemon")
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 a = ("apple","banana","mango","kiwi","lemon")
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
tup = (2,4,6,8,10)
a, *b, c = tup
print(a)
print(b)
print(c)
# Out:
# 2
# [4, 6, 8]
# 10

# %%
a = ("apple","banana","mango","kiwi","lemon")
res = tuple(reversed(a))
print(res)
# Out:
# ('lemon', 'kiwi', 'mango', 'banana', 'apple')

# %%
a = ("apple","banana","mango","kiwi","lemon")
b = list(a)
print(b)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'lemon']

# %%
a = [("a",1),("b",2),("c",3)]
res = dict(a)
print(res)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
a = ("apple","banana","mango","kiwi","lemon")
b = (2,4,6,8,10)
c = a + b
print(c)
# Out:
# ('apple', 'banana', 'mango', 'kiwi', 'lemon', 2, 4, 6, 8, 10)

# %%
a = ("apple","banana","mango","kiwi","lemon")
b = (2,4,6,8,10)
part1 = a[3:]
part2 = b[3:]
update_tuple = part1 + part2
print(update_tuple)
# Out:
# ('kiwi', 'lemon', 8, 10)

# %%
a = ("apple","banana","mango","lemon")
b = list(a)
b[2] = "kiwi"
c = tuple(b)
print(c)
# Out:
# ('apple', 'banana', 'kiwi', 'lemon')

# %%
a = ("apple","banana","mango","lemon")
b = list(a)
b.append("kiwi")
c = tuple(b)
print(c)
# Out:
# ('apple', 'banana', 'mango', 'lemon', 'kiwi')

# %%
a = ("apple","banana","mango","lemon")
b = list(a)
b.remove("mango")
c= tuple(b)
print(c)
# Out:
# ('apple', 'banana', 'lemon')

# %%
a = ("apple","banana","mango","lemon")
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 a = ("apple","banana","mango","lemon")
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
a = ("apple","banana","mango","lemon")
for i in a:
    print(i)
# Out:
# apple
# banana
# mango
# lemon

# %%
a = ("apple","banana","mango","lemon")
i=0
while i<len(a):
    print(a[i])

    i += 1
# Out:
# apple
# banana
# mango
# lemon

# %%
tup1 = (25, 12, 10, -21, 10, 100)
x = tup1.count(25)
print(x)
# Out:
# 1

# %%
tup1 = ("one","two","three","four")
x = tup1.index("three")
print(x)
# Out:
# 2
