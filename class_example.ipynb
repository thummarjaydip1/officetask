# %% [markdown]
# ## Python Class

# %%
class Myclass:
    x=5
print(Myclass)
# Out:
# <class '__main__.Myclass'>

# %%
class Myclass:
    x= 5
p1 = Myclass()
print("X : ",p1.x)
# Out:
# X :  5

# %%
class Myclass:
    x=5
    y=6
    z=7
p1 = Myclass()
p2 = Myclass()
p3 = Myclass()
print("p1 object x value:",p1.x)
print("p1 object y value:",p1.y)
print("p1 object z value:",p1.z)
print("p2 object x value:",p2.x)
print("p2 object y value:",p2.y)
print("p2 object z value:",p2.z)
print("p3 object x value:",p3.x)
print("p3 object y value:",p3.y)
print("p3 object z value:",p3.z)
# Out:
# p1 object x value: 5
# p1 object y value: 6
# p1 object z value: 7
# p2 object x value: 5
# p2 object y value: 6
# p2 object z value: 7
# p3 object x value: 5
# p3 object y value: 6
# p3 object z value: 7

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def myfunc(self):
        print(f"hello my name is: {self.name}")
        print(f"age is: {self.age}")
p1 = Person("jaydip",21)
# p1.myfunc()
del p1   # p1 are deleted generate error
print(p1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[334], line 11
#       9 # p1.myfunc()
#      10 del p1   # p1 are deleted generate error
# ---> 11 print(p1)
#
# NameError: name 'p1' is not defined

# %%
class person:
    pass
p1= person()
print(p1)

# %%
class Myclass:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def greet(self):
        print("Hello My name is:",self.name, "age is:",self.age)
p1 = Myclass("john",36)
p1.greet()
# Out:
# Hello My name is: john age is: 36

# %%
class Myclass:
    def __init__(self,name,age):
        self.name = name
        self.age = age
x = Myclass("jaydip",21)
print("name:"+x.name)
print("age:"+str(x.age)) 
print(x.age)# string and integer bane one print ma no lakhi sakay int ne str ma convert karvu pade
# Out:
# name:jaydip
# age:21
# 21

# %%
class Myclass:
    pass
p1= Myclass()
p1.name = "jaydip"
p1.age = 21
p1.city = "surat"
print(p1.name)
print(p1.age)
print(p1.city)
# Out:
# jaydip
# 21
# surat

# %%
class Myclass:
    def __init__(self,name,age=21):
        self.name = name
        self.age = age
p1 = Myclass("jay")
p2 = Myclass("dip",23)
print("name age")
print(p1.name, p1.age)
print(p2.name, p2.age)
# Out:
# name age
# jay 21
# dip 23

# %%
class Myclass:
    def __init__(self,name,age,city,country):
        self.name = name
        self.age = age
        self.city = city
        self.country = country
p1= Myclass("jaydip",21,"amreli","india")
print(p1.name, end=" ")
print(p1.age, end=" ")
print(p1.city, end=" ")
print(p1.country,end=" ")
# Out:
# jaydip 21 amreli india

# %%
class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def bark(self):
        print(self.name+ " says woof!")
d1= Dog("Buddy",3)
d1.bark()
# Out:
# Buddy says woof!

# %%
class Myclass:
    def __init__(self,name,city):
        self.name = name
        self.city = city
    def printname(self):
        print("name is: "+self.name)
    def printcity(self):
        print("city is: "+self.city)
x = Myclass("jaydip", "surat")
y = Myclass("ram","amreli")
print("p1 object")
x.printname()
x.printcity()
print("p2 object")
y.printname()
y.printcity()
# Out:
# p1 object
# name is: jaydip
# city is: surat
# p2 object
# name is: ram
# city is: amreli

# %%
class Myclass:       # It does not have to be named self, you can call it whatever you like, but it has to be the first parameter of any method in the class:
    def __init__(myobj,name,age):
        myobj.name = name
        myobj.age = age
    def greet(abc):
        print("name is: ",abc.name,"age is:",abc.age)
x= Myclass("jaydip",22)
x.greet()
# Out:
# name is:  jaydip age is: 22

# %%
class Car:
    def __init__(self,brand,model,year):
        self.brand = brand
        self.model = model
        self.year = year
    def display_info(self):
        print(f"{self.year} {self.brand} {self.model}")
c1=Car("toyota","corolla",2020)
c1.display_info()
# Out:
# 2020 toyota corolla

# %%
class Myclass:
    def __init__(self,name):
        self.name = name
    def greet(self):
        return "Hello " + self.name
    def disp(self):
        message= self.greet()
        print(message,"welcome to my website!")
m1 =Myclass("jaydip")
m1.disp()
# Out:
# Hello jaydip welcome to my website!

# %%
class Car:
    def __init__(self,brand):
        self.brand = brand
    def show(self):
        print("brand of car: "+self.brand)
c1 = Car("Ford")
c1.show()
# Out:
# brand of car: Ford

# %%
class Car:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
c1 = Car(x,y)
x ="Toyota"
y ="corolla"
print(c1.brand)
print(c1.model)
# Out:
# Toyota
# corolla

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
p1 = Person("john",31)
print(p1.age)
p1.age = 40
print(p1.age)
# Out:
# 31
# 40

# %%
class Person:
    def __init__(self,name,age):
        self.name= name
        self.age= age
p1 = Person("jaydip",35)
print(p1.name)
print(p1.age)
del p1.age
print(p1.name)
print(p1.age)  # age perameter delete kari nakho che etale error show thay
# Out:
# jaydip
# 35
# jaydip
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 10
#       8 del p1.age
#       9 print(p1.name)
# ---> 10 print(p1.age)  # age perameter delete kari nakho che etale error show thay
#
# AttributeError: 'Person' object has no attribute 'age'

# %%
class Myclass:
    species = "parth"
    def __init__(self,name):
        self.name = name
p1 = Myclass("jay")
p2 = Myclass("dip")
print(p1.name)
print(p2.name)
print(p1.species)
print(p2.species)
# Out:
# jay
# dip
# parth
# parth

# %%
class Myclass:
    lastname=""
    def __init__(self,name):
        self.name =name
p1 = Myclass("jay")
p2 = Myclass("dip")
Myclass.lastname = "jaydip"
print(p1.lastname)
print(p2.lastname)
print(p1.name)
print(p2.name)
# Out:
# jaydip
# jaydip
# jay
# dip

# %%
class Myclass:
    def __init__(self,name):
        self.name = name
x = Myclass("jaydip")
x.age = 23
x.city = "AMRELI"
print(x.name)
print(x.age)
print(x.city)
# Out:
# jaydip
# 23
# AMRELI

# %%
class Student:
    def __init__(self,name,grade):
        self.name = name
        self.grade = grade
s1 = Student("Anna","A")
print("Before Update")
print("name is:"+s1.name)
print("grade  is:"+s1.grade)

s1.grade = "B"

print("After update")
print("name is:"+s1.name)
print("grade  is:"+s1.grade)
# Out:
# Before Update
# name is:Anna
# grade  is:A
# After update
# name is:Anna
# grade  is:B

# %%
class Calculator:
    def add(self,a,b):
        return a + b
    def multi(self,a,b):
        return a * b
c1= Calculator()
print("addition is:",c1.add(10,20))
print("multiplication is:",c1.multi(10,20))
# Out:
# addition is: 30
# multiplication is: 200

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def get_info(self):
        return f"{self.name} is {self.age} years old."
p1 = Person('jaydip',21)
print(p1.get_info())
# Out:
# jaydip is 21 years old.

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def celebrate_birthday(self):
        self.age += 1
        print(f"Happy birthday! you are now {self.age}")
p1= Person("jaydip",20)
p1.celebrate_birthday()
p1.celebrate_birthday()
# Out:
# Happy birthday! you are now 21
# Happy birthday! you are now 22

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def __str__(self):
        return f"name is:{self.name} age is:{self.age}"
p1 = Person("jaydip",21)
print(p1)
# Out:
# name is:jaydip age is:21

# %%
class Playlist:
    def __init__(self,name):
        self.name = name
        self.songs = []
    def add_song(self,song):
        self.songs.append(song)
        print(f"added song: {song}")
    def removed_song(self,song):
        self.songs.remove(song)
        print(f"remved song: {song}")
    def show_song(self):
        print(f"Playlist : {self.name}")
        for song in self.songs:
            print(f"- {song}")
p1 = Playlist("favorite")
p1.add_song("dilbar")
p1.add_song("maheboob")
p1.add_song("lalpari")
p1.add_song("chand shifaris")
p1.removed_song("dilbar")
p1.show_song()
# Out:
# added song: dilbar
# added song: maheboob
# added song: lalpari
# added song: chand shifaris
# remved song: dilbar
# Playlist : favorite
# - maheboob
# - lalpari
# - chand shifaris

# %%
class Myclass:
    def __init__(self,name):
        self.name = name
    def greet(self):
        print(f"name is:{self.name}")
x= Myclass("mahesh")
print("after delete greet method")
x.greet()
print("before delete greet method")
del x.greet
x.greet()
# Out:
# after delete greet method
# name is:mahesh
# before delete greet method
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[123], line 10
#       8 x.greet()
#       9 print("before delete greet method")
# ---> 10 del x.greet
#      11 x.greet()
#
# AttributeError: 'Myclass' object has no attribute 'greet'

# %%
class Rectangle:
    def __init__(self,height,width):
        self.height = height
        self.width = width
    def area(self):
        return self.height * self.width
r1 = Rectangle(3,5)
print(f"area of: {r1.area()}")
# Out:
# area of: 15

# %% [markdown]
# ##### Python Inheritance

# %%
class Person:
    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname
    def printname(self):
        print(self.fname,self.lname)

class Myclass(Person):
    pass
x= Myclass("jaydip","thummar")
x.printname()
# Out:
# jaydip thummar

# %%
class Person:
    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname
    def printname(self):
        print(self.fname,self.lname)
class Myclass(Person):
    def __init__(self, fname, lname):
        Person.__init__(self,fname, lname)
x = Myclass("jaydip","thummar")
x.printname()
# Out:
# jaydip thummar

# %%
class Person:
    def __init__(self,fname,lname):
        self.firstname = fname
        self.lastname = lname
    def printname(self):
        print(self.firstname,self.lastname)
class Myclass(Person):
    def __init__(self, fname, lname):
        super().__init__(fname, lname)
x=Myclass("jaydip","thummar")
x.printname()

# class Student(Person):
#     def __init__(self, fname, lname, grade):
#         super().__init__(fname, lname)
#         self.grade = grade
# Out:
# jaydip thummar

# %%
class Person:
    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname
    def printname(self):
        print(self.fname,self.lname)
class Student(Person):
    def __init__(self, fname, lname):
        super().__init__(fname, lname)
        self.graduationyear = 2020
x = Student("jay","desai")
x.printname()
print(x.graduationyear)
# Out:
# jay desai
# 2020

# %%
class Person:
    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname
    def printname(self):
        print(self.fname,self.lname)
class Student(Person):
    def __init__(self,fname,lname,year):
        super().__init__(fname,lname)
        self.graduationyear = year
    def wecome(self):
        print(f"wecome {self.fname}, {self.lname} to the class of {self.graduationyear}")
x = Student("jay","desai",2020)
x.printname()
x.wecome()
# Out:
# jay desai
# wecome jay, desai to the class of 2020

# %%
class Animmal:
    def __init__(self,name):
        self.name = name
    def speak(self):
        print(f"Dog name is: {self.name}")
class Dog(Animmal):
    pass
d1 = Dog("Rex")
d1.speak()
# Out:
# Dog name is: Rex

# %% [markdown]
# ### Python Polymorphism

# %%
x = "hello world"
print(len(x))
# Out:
# 11

# %%
mytuple= ('apple','banana','mango','kiwi')
print(len(mytuple))
# Out:
# 4

# %%
mydict={
    'name':'jay',
    'city':'rjk',
    'age':20
}
print(len(mydict))
# Out:
# 3

# %%
class Car:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
    def move(self):
        print("drive")
        
class Boat:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
    def move(self):
        print("spail")

class Plain:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
    def move(self):
        print("fly")

car1 = Car("ford","mustang")
boat1 = Boat("ibiza","touring 20")
plain1= Plain("Boeing","747")
for x in (car1, boat1, plain1):
    x.move()
    print(f"brand:{x.brand}")
    print(f"model:{x.model}")
# Out:
# drive
# brand:ford
# model:mustang
# spail
# brand:ibiza
# model:touring 20
# fly
# brand:Boeing
# model:747

# %%
class Vehicle:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
    def move(self):
        print("move")
class Car(Vehicle):
    pass
class Boat(Vehicle):
    def move(self):
        print("sail")
class Plane(Vehicle):
    def move(self):
        print('fly')
car1 = Car("Ford", "Mustang")       
boat1 = Boat("Ibiza", "Touring 20") 
plane1 = Plane("Boeing", "747")     
for i in (car1,boat1,plane1):
    print(i.brand)
    print(i.model)
    i.move()
# Out:
# Ford
# Mustang
# move
# Ibiza
# Touring 20
# sail
# Boeing
# 747
# fly

# %%
class Cat:
    def sound(self):
        print("Meow")
class Fox:
    def sound(self):
        print("Wa-pa-pa-pa-pa-pow")
c1 = Cat()
f1 = Fox()
# for i in (c1,f1):
    # i.sound()
c1.sound()
f1.sound()
# Out:
# Meow
# Wa-pa-pa-pa-pa-pow

# %% [markdown]
# #### Python Encapsulation

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.__age = age
p1 = Person("jay",23)
print(p1.name)
print(p1.__age)
# Out:
# jay
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[215], line 7
#       5 p1 = Person("jay",23)
#       6 print(p1.name)
# ----> 7 print(p1.__age)
#
# AttributeError: 'Person' object has no attribute '__age'

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.__age = age
    def get_age(self):
        print(f"age is: {self.__age}")
p1= Person("jay",23)
print("name is:",p1.name)
p1.get_age()
# Out:
# name is: jay
# age is: 23

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.__age = age
    def get_age(self):
        return self.__age
    def set_age(self,age):
        if age > 0:
            self.__age = age
        else:
            print("enter integer no")
p1 = Person("jay",23)
print(p1.get_age())
p1.set_age(55)
print(p1.get_age())
# Out:
# 23
# 55

# %%
class Student:
    def __init__(self,name):
        self.name = name
        self.__grade = 0
    def set_grade(self,grade):
        if 0<= grade <=100:
            self.__grade = grade
        else:
            print("guest must be between 0 and 100")
    def get_grade(self):
        return self.__grade
    def get_result(self):
        if self.__grade >=60:
            return "Pass"
        else:
            return "Fail"
s1 = Student("jaydip")
a=int(input("enter any no(1-100)"))
s1.set_grade(a)
print(f"grade: {s1.get_grade()}")
print(f"result: {s1.get_result()}")
# Out:
# grade: 88
# result: Pass

# %%
class Person:
    def __init__(self,name,salary):
        self.name =name
        self._salary =salary
p1= Person("jay",12000)
print(p1.name)
print(p1._salary)
# Out:
# jay
# 12000

# %%
class Calculator:
    def __init__(self):
        self.result = 0
    def __validate(self,num):
        if not isinstance(num,(int,float)):
            return False
        return True
    def add(self,num):
        if self.__validate(num):
            self.result += num
        else:
            print("Invalid Number")
cal =Calculator()
cal.add(10)
cal.add(5)
print(cal.result)
# Out:
# 15

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.__age = age
p1 = Person("jay",23)
print(p1._Person__age)
# Out:
# 23

# %%
class ScoreBoard:
    def __init__(self,score):
        self.__score = score
    def get_score(self):
        return self.__score
s1= ScoreBoard(0)
print(s1.get_score())
# Out:
# 0

# %% [markdown]
# #### Python Inner Class

# %%
class Outer:
    def __init__(self):
        self.name = "outer class"
    
    class Inner:
        def __init__(self):
            self.name = "inner class"
        def display(self):
            print("this is inner class method")
out=Outer()
print(out.name)
# Out:
# outer class

# %%
class Outer:
    def __init__(self):
        self.name="outer class"
    class Inner:
        def __init__(self):
            self.name="inner class"
        def display(self):
            print("this is inner class method")
outer = Outer()  # outer class object
print(outer.name)
inner = outer.Inner()   # inner class object
print(inner.name)
inner.display()
# Out:
# outer class
# inner class
# this is inner class method

# %%
class Outer:
    def __init__(self):
        self.name= "jaydip"
    class Inner:
        def __init__(self,outer):
            self.outer = outer
        def display(self):
            print(f"Outer class name: {self.outer.name}")
outer = Outer()
inner = outer.Inner(outer)
inner.display()
# Out:
# Outer class name: jaydip

# %%
class Car:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
        self.engine = self.Engine()
        
    class Engine:
        def __init__(self):
            self.status ="Off"
        def start(self):
            self.status = "Running"
            print("Engine is started")
        def stop(self):
            self.status = "Off"
            print("Engine is stoped")

    def drive(self):
        if self.engine.status == "Running":
            print(f"Driving the {self.brand} {self.model}")
        else:
            print("start the engine first")
car= Car("Toyota","corolla")
car.drive()
car.engine.start()
car.drive()
car.engine.stop()
car.drive()
# Out:
# start the engine first
# Engine is started
# Driving the Toyota corolla
# Engine is stoped
# start the engine first

# %%
class Computer:
    def __init__(self):
        self.cpu = self.CPU()
        self.ram = self.RAM()
    
    class CPU:
        def process(self):
            print("processing data..........")
    
    class RAM:
        def store(self):
            print("Storing data.............")
com = Computer()
com.cpu.process()
com.ram.store()
# Out:
# processing data..........
# Storing data.............
