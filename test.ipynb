# %%
# 1
for i in range(1,6,1):
    print("*")
# Out:
# *
# *
# *
# *
# *

# %%
# 6
nums = [1, 2, 2, 3, 4, 4, 5]
nums.remove(2)  
nums.remove(4)
print(nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7
t = (("a", 1), ("b", 2), ("c", 3))
mydict = dict(t)
print(mydict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
data = [1, 2, 2, 3, 3, 3, 4]
y = "numbers"
thisdict = dict.fromkeys(data,y)
print(thisdict)
# Out:
# {1: 'numbers', 2: 'numbers', 3: 'numbers', 4: 'numbers'}

# %%
# 9
a = [1, 2, 3, 4]
b = [3, 4, 5, 6]
x= set(a)
y= set(b)
myset = x.intersection(y)
mylist = list(myset)
print(mylist)
# Out:
# [3, 4]

# %%
# 10
d = {"a": 10, "b": 20, "c": 30}
.keys()
.va
a=dict.fromkeys(d)
print(d)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
# 11
a= int(input("enter any no:"))
print(a)
if a%2==0:
    print("even no")
else:
    print("odd no")
# Out:
# 11
# odd no

# %%
# 12
for i in range(1,51,1):
    print(i)

j=1
while j<=50:
    print(j)
    j+=1

# %%
# 13
a=int(input("enter any no:"))
b=1
i=1
while i<=a:
    b=b*a
    i+=1
print(b)
# Out:
# 3125

# %%
# 14

# %%
# 15
import random
b= random.randrange(1,50)
print(b)
for i in range(5):
    a= int(input("enter any no(1-50)"))
    if a==b:
        print("your no is matched")
    elif a<b:
        print("your no is low")
    elif a>b:
        print("your no is high")
    else:
        print("enter your correct number")
print("Ends when guessed correctly or attempts finish")
# Out:
# 4
# your no is high
# your no is matched
# your no is low
# your no is low
# your no is high
# Ends when guessed correctly or attempts finish
