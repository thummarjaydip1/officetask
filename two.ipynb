# %% [markdown]
# # Python List

# %%
thislist= ['apple','banana','mango',"apple","pineapple"]
print(thislist)
# Out:
# ['apple', 'banana', 'mango', 'apple', 'pineapple']

# %%
a= ['apple','banana','mango']
print(len(a))
# Out:
# 3

# %%
list1 = ["apple", "banana", "mango"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'mango']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
list1 = ["abc", 34, True, 40, "male"]
print(list1)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
list1= ['apple','banana','mango']
print(type(list1))
# Out:
# <class 'list'>

# %%
list1= ['apple','banana','mango']
print(list1[1])
# Out:
# banana

# %%
list1= ['apple','banana','mango']
print(list1[-1])
# Out:
# mango

# %%
list1= ['apple','banana','mango','cherry','kiwi','melon','orange']
print(list1[2:6])
# Out:
# ['mango', 'cherry', 'kiwi', 'melon']

# %%
list1= ['apple','banana','mango','cherry','kiwi','melon','orange']
print(list1[:4])
# Out:
# ['apple', 'banana', 'mango', 'cherry']

# %%
list1= ['apple','banana','mango','cherry','kiwi','melon','orange']
print(list1[3:])
# Out:
# ['cherry', 'kiwi', 'melon', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[-4:-1])
# Out:
# ['orange', 'kiwi', 'melon']

# %%
thislist= ['apple','banana','mango']
if 'apple' in thislist:
    print("yes, 'apple' in this list")
# Out:
# yes, 'apple' in this list

# %%
thislist = ['aaple','banana','mango']
print(thislist)
thislist[0]=['apple']
print(thislist)
# Out:
# ['aaple', 'banana', 'mango']
# [['apple'], 'banana', 'mango']

# %%
thislist = ['apple','banana','cherry','mango','kiwi']
print(thislist)
thislist[1:3]=["blackcurrant","watermelon"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'kiwi']
# ['apple', 'blackcurrant', 'watermelon', 'mango', 'kiwi']

# %%
thislist= ['apple','banana','mango']
print(thislist)
thislist.insert(2,"kiwi")
print(thislist)
# Out:
# ['apple', 'banana', 'mango']
# ['apple', 'banana', 'kiwi', 'mango']

# %%
thislist= ['apple','banana','mango']
print(thislist)
thislist.append("kiwi")
print(thislist)
# Out:
# ['apple', 'banana', 'mango']
# ['apple', 'banana', 'mango', 'kiwi']

# %%
thislist= ['apple','banana','mango']
list1= ['kiwi','watermelon']
thislist.extend(list1)
print(thislist)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 'watermelon']

# %%
thislist= ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
thislist= ["apple", "banana", "cherry"]
thislist.pop()
print(thislist)
# Out:
# ['apple', 'banana']

# %%
thislist= ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist= ['apple','banana','mango']
del thislist

# %%
thislist= ['apple','banana','manogo']
thislist.clear()
print(thislist)
# Out:
# []

# %%
thislist= ['apple','banana','manogo']
for x in thislist:
    print(x)
# Out:
# apple
# banana
# manogo

# %%
thislist= ['apple','banana','manogo']
for i in range(len(thislist)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
thislist= ['apple','banana','mango']
i=0
while i < len(thislist):
    print(thislist[i])
    i=i+1
# Out:
# apple
# banana
# mango

# %%
fruits= ['apple', 'mango', 'kiwi,','banana']
newlist= []
for x in fruits:
    if "a" in x:
        newlist.append(x)
print(newlist)
# Out:
# ['apple', 'mango', 'banana']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x for x in fruits if "a" in x]
print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x for x in fruits if x!="apple" and x!="kiwi"]
print(newlist)
# Out:
# ['banana', 'cherry', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist= [x.upper() for x in fruits]
print(newlist)
# Out:
# ['APPLE', 'BANANA', 'CHERRY', 'KIWI', 'MANGO']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist= ["hello" for x in fruits]
print(newlist)
# Out:
# ['hello', 'hello', 'hello', 'hello', 'hello']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x if x != "banana" else "orange" for x in fruits]
print(newlist)
# Out:
# ['apple', 'orange', 'cherry', 'kiwi', 'mango']

# %%
fruits = ["apple", "banana", "kiwi", "cherry", "mango"]
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'mango']

# %%
fruits = ["apple", "banana", "kiwi", "cherry", "mango"]
fruits.sort(reverse=True)
print(fruits)
# Out:
# ['mango', 'kiwi', 'cherry', 'banana', 'apple']

# %%
fruits = [43,76,35,89,23,12]
fruits.sort()
print(fruits)
# Out:
# [12, 23, 35, 43, 76, 89]

# %%
fruits = [43,76,35,89,23,12]
fruits.sort(reverse=True)
print(fruits)
# Out:
# [89, 76, 43, 35, 23, 12]

# %%
fruits = ["apple", "banana", "kiwi", "cherry", "mango"]
fruits.reverse()
print(fruits)
# Out:
# ['mango', 'cherry', 'kiwi', 'banana', 'apple']

# %%
thislist = ["apple", "banana", "kiwi", "cherry", "mango"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'kiwi', 'cherry', 'mango']

# %%
thislist = ["apple", "banana", "kiwi", "cherry", "mango"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'kiwi', 'cherry', 'mango']

# %%
list1= ['a','b','c']
list2= [2,4,6]
list3= list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 2, 4, 6]

# %%
list1= ['a','b','c']
list2= [2,4,6]
for x in list2:
    list1.append(x)
print(list1)
# Out:
# ['a', 'b', 'c', 2, 4, 6]

# %% [markdown]
# # Python Tuples

# %%
thistuple= ('apple','banana','mango','cherry','kiwi')
print(thistuple)
# Out:
# ('apple', 'banana', 'mango')

# %%
thistuple= ('apple','banana','mango','cherry','kiwi')
print(len(thistuple))
# Out:
# 5

# %%
thistuple= ('apple','banana','mango','watermelon','cherry','kiwi')
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
tuple1= ('apple','cherry','kiwi')
tuple2= (1,2,3,4,5)
tuple3= (True,False,False)
print(tuple1)
print(tuple2)
print(tuple3)
# Out:
# ('apple', 'cherry', 'kiwi')
# (1, 2, 3, 4, 5)
# (True, False, False)

# %%
tuple1 =("abc",34,True,40,"male")
print(tuple1)
# Out:
# ('abc', 34, True, 40, 'male')

# %%
tuple1= tuple(('apple','cherry','kiwi'))
print(tuple1)
# Out:
# ('apple', 'cherry', 'kiwi')

# %%
thistuple= ('apple','banana','mango','watermelon','cherry','kiwi')
print(thistuple[1])
# Out:
# banana

# %%
thistuple= ('apple','banana','mango','watermelon','cherry','kiwi')
print(thistuple[-1])
# Out:
# kiwi

# %%
thistuple= ('apple','banana','mango','watermelon','cherry','kiwi')
print(thistuple[2:5])
# Out:
# ('mango', 'watermelon', 'cherry')

# %%
thistuple= ('apple','banana','mango','watermelon','cherry','kiwi')
print(thistuple[:4])
# Out:
# ('apple', 'banana', 'mango', 'watermelon')

# %%
thistuple= ('apple','banana','mango','watermelon','cherry','kiwi')
print(thistuple[2:])
# Out:
# ('mango', 'watermelon', 'cherry', 'kiwi')
